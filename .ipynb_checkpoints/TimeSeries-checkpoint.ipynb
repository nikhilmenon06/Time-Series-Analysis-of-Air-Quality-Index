# %%
import pandas as pd
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("PRSA_Data_Dingling_20130301-20170228.csv", encoding = 'ISO-8859-1')

# %%
display(df)
# Out:
#           No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO     O3  \
# 0          1  2013      3    1     0    4.0   4.0  3.0  NaN  200.0   82.0
# 1          2  2013      3    1     1    7.0   7.0  3.0  NaN  200.0   80.0
# 2          3  2013      3    1     2    5.0   5.0  3.0  2.0  200.0   79.0
# 3          4  2013      3    1     3    6.0   6.0  3.0  NaN  200.0   79.0
# 4          5  2013      3    1     4    5.0   5.0  3.0  NaN  200.0   81.0
# ...      ...   ...    ...  ...   ...    ...   ...  ...  ...    ...    ...
# 35059  35060  2017      2   28    19   11.0  11.0  2.0  2.0  200.0   99.0
# 35060  35061  2017      2   28    20   13.0  13.0  2.0  2.0  200.0  101.0
# 35061  35062  2017      2   28    21    9.0  14.0  2.0  2.0  200.0  102.0
# 35062  35063  2017      2   28    22   10.0  12.0  2.0  2.0  200.0   97.0
# 35063  35064  2017      2   28    23   13.0  16.0  4.0  9.0  500.0   74.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM   station
# ...

# %%
def dateparser(x):
    return datetime.strptime(x,"%Y %m %d %H")

# %%
# Read the date and convert into a concatenated date time object. Adds a new column with the date object created by concatenating the individual date aspects.

df = pd.read_csv("PRSA_Data_Dingling_20130301-20170228.csv", encoding = 'ISO-8859-1',parse_dates = [['year','month','day','hour']], date_parser = dateparser, keep_date_col = True )

# %%
display(df)
df.describe()
df.info()
# Out:
#       year_month_day_hour     No  year month day hour  PM2.5  PM10  SO2  NO2  \
# 0     2013-03-01 00:00:00      1  2013     3   1    0    4.0   4.0  3.0  NaN
# 1     2013-03-01 01:00:00      2  2013     3   1    1    7.0   7.0  3.0  NaN
# 2     2013-03-01 02:00:00      3  2013     3   1    2    5.0   5.0  3.0  2.0
# 3     2013-03-01 03:00:00      4  2013     3   1    3    6.0   6.0  3.0  NaN
# 4     2013-03-01 04:00:00      5  2013     3   1    4    5.0   5.0  3.0  NaN
# ...                   ...    ...   ...   ...  ..  ...    ...   ...  ...  ...
# 35059 2017-02-28 19:00:00  35060  2017     2  28   19   11.0  11.0  2.0  2.0
# 35060 2017-02-28 20:00:00  35061  2017     2  28   20   13.0  13.0  2.0  2.0
# 35061 2017-02-28 21:00:00  35062  2017     2  28   21    9.0  14.0  2.0  2.0
# 35062 2017-02-28 22:00:00  35063  2017     2  28   22   10.0  12.0  2.0  2.0
# 35063 2017-02-28 23:00:00  35064  2017     2  28   23   13.0  16.0  4.0  9.0
#
# ...

# %%
df_non_index = df.copy()

# %%
# Time Series data should be indexed by the time object. Makes querying, subsetting (loc,iloc) etc easier and faster.
df = df.set_index("year_month_day_hour")
df[['year','month']] = df[['year','month']].apply(pd.to_numeric,axis =1)

# %%
display(df)
# df.info()
# Out:
#                         No  year  month day hour  PM2.5  PM10  SO2  NO2  \
# year_month_day_hour
# 2013-03-01 00:00:00      1  2013      3   1    0    4.0   4.0  3.0  NaN
# 2013-03-01 01:00:00      2  2013      3   1    1    7.0   7.0  3.0  NaN
# 2013-03-01 02:00:00      3  2013      3   1    2    5.0   5.0  3.0  2.0
# 2013-03-01 03:00:00      4  2013      3   1    3    6.0   6.0  3.0  NaN
# 2013-03-01 04:00:00      5  2013      3   1    4    5.0   5.0  3.0  NaN
# ...                    ...   ...    ...  ..  ...    ...   ...  ...  ...
# 2017-02-28 19:00:00  35060  2017      2  28   19   11.0  11.0  2.0  2.0
# 2017-02-28 20:00:00  35061  2017      2  28   20   13.0  13.0  2.0  2.0
# 2017-02-28 21:00:00  35062  2017      2  28   21    9.0  14.0  2.0  2.0
# 2017-02-28 22:00:00  35063  2017      2  28   22   10.0  12.0  2.0  2.0
# 2017-02-28 23:00:00  35064  2017      2  28   23   13.0  16.0  4.0  9.0
#
#                         CO     O3  TEMP    PRES  DEWP  RAIN   wd  WSPM  \
# ...

# %% [markdown]
# ## Exploratory Analysis

# %%
# Plot PM10 for a specific year (2016,2015 or 2014 anything)

df_2014 = df.loc['2014'].reset_index()
# df_2015 = df.loc['2015'].reset_index()
# df_2014['month_day_hour'] = df_2014.apply(lambda x: str(x['month']) + '-' + x['day'],axis = 1)
# df_2015['month_day_hour'] = df_2015.apply(lambda x: str(x['month']) + '-' + x['day'],axis = 1)

df_2014_temp = df_2014[["PM2.5","month","day"]].groupby(['month','day'],as_index='False')['PM2.5'].mean()
plt.plot(df_2014_temp['month'],df_2014_temp['PM2.5'])
# plt.plot(df_2015['month_day_hour'],df_2015['PM2.5'])
plt.xlabel('Month')
plt.ylabel("PM 2.5")
plt.legend(["2014"])
plt.title("Air Quality Index - 2014")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'month'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-143-e622a5c5df68> in <module>
#       7
#       8 df_2014_temp = df_2014[["PM2.5","month","day"]].groupby(['month','day'],as_index='False')['PM2.5'].mean()
# ...

# %%
df_2014_temp = df_2014.groupby(['month','day'],as_index='False')['PM2.5'].mean()

# %%
df_2014_temp2 = df_2014_temp.reset_index()
display(df_2014_temp2)
# Out:
#      month day       PM2.5
# 0        1   1   34.291667
# 1        1  10   39.791667
# 2        1  11   56.625000
# 3        1  12   16.750000
# 4        1  13   60.500000
# ..     ...  ..         ...
# 360     12   5   15.083333
# 361     12   6   44.583333
# 362     12   7   53.000000
# 363     12   8   74.086957
# 364     12   9  189.791667
#
# [365 rows x 3 columns]

# %%
# df_2014 = df_2014[["PM2.5","month","day"]].groupby(['month','day']).agg({'PM2.5':['mean']})
display(df_2014)
# Out:
#      year_month_day_hour     No  year  month day hour  PM2.5   PM10   SO2  \
# 0    2014-01-01 00:00:00   7345  2014      1   1    0   27.0  104.0  12.0
# 1    2014-01-01 01:00:00   7346  2014      1   1    1   25.0   86.0  12.0
# 2    2014-01-01 02:00:00   7347  2014      1   1    2   27.0   85.0  14.0
# 3    2014-01-01 03:00:00   7348  2014      1   1    3   34.0   98.0  19.0
# 4    2014-01-01 04:00:00   7349  2014      1   1    4   32.0  102.0  18.0
# ...                  ...    ...   ...    ...  ..  ...    ...    ...   ...
# 8755 2014-12-31 19:00:00  16100  2014     12  31   19    7.0   37.0   2.0
# 8756 2014-12-31 20:00:00  16101  2014     12  31   20    NaN    NaN   NaN
# 8757 2014-12-31 21:00:00  16102  2014     12  31   21    NaN    NaN   NaN
# 8758 2014-12-31 22:00:00  16103  2014     12  31   22    NaN    NaN   NaN
# 8759 2014-12-31 23:00:00  16104  2014     12  31   23    NaN    NaN   NaN
#
#        NO2     CO    O3  TEMP    PRES  DEWP  RAIN   wd  WSPM   station
# ...
